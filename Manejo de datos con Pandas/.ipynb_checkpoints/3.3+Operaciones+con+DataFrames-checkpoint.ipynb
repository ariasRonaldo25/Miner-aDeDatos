# %% [markdown]
# <font color=Green>
#
# # **3.3 Operaciones con DataFrames**
#
# </font>

# %%
import numpy as np
import pandas as pd

# %%
d = [np.random.randint(50,size=(10))]
d
# Out:
# [array([22, 17, 15, 37,  7,  7, 42, 30, 35, 47])]

# %%
df = pd.DataFrame(d).T
df
# Out:
#     0
# 0  22
# 1  17
# 2  15
# 3  37
# 4   7
# 5   7
# 6  42
# 7  30
# 8  35
# 9  47

# %% [markdown]
# ## <font color=#003d5c>_Añadir una nueva columna_ </font>

# %%
df['nueva_col'] = 10

# %%
df['experiencia'] = 5

df
# Out:
#     0  nueva_col  experiencia
# 0  22         10            5
# 1  17         10            5
# 2  15         10            5
# 3  37         10            5
# 4   7         10            5
# 5   7         10            5
# 6  42         10            5
# 7  30         10            5
# 8  35         10            5
# 9  47         10            5

# %%
df['perdidas'] = [(i+2)*np.e for i in range(10)]

df
# Out:
#     0  nueva_col  experiencia   perdidas
# 0  22         10            5   5.436564
# 1  17         10            5   8.154845
# 2  15         10            5  10.873127
# 3  37         10            5  13.591409
# 4   7         10            5  16.309691
# 5   7         10            5  19.027973
# 6  42         10            5  21.746255
# 7  30         10            5  24.464536
# 8  35         10            5  27.182818
# 9  47         10            5  29.901100

# %%
df['columna'] = df['perdidas']*100
df
# Out:
#     0  nueva_col  experiencia   perdidas      columna
# 0  22         10            5   5.436564   543.656366
# 1  17         10            5   8.154845   815.484549
# 2  15         10            5  10.873127  1087.312731
# 3  37         10            5  13.591409  1359.140914
# 4   7         10            5  16.309691  1630.969097
# 5   7         10            5  19.027973  1902.797280
# 6  42         10            5  21.746255  2174.625463
# 7  30         10            5  24.464536  2446.453646
# 8  35         10            5  27.182818  2718.281828
# 9  47         10            5  29.901100  2990.110011

# %% [markdown]
# ## <font color=#003d5c>_Cambiar el nombre de una columna_ </font>

# %%
df.columns
# Out:
# Index([0, 'nueva_col', 'experiencia', 'perdidas', 'columna'], dtype='object')

# %%
df.columns = ['codigo_id','años_exp', 'indice', 'eficiencia','eficiencia_agregada']

df
# Out:
#    codigo_id  años_exp  indice  eficiencia  eficiencia_agregada
# 0         22        10       5    5.436564           543.656366
# 1         17        10       5    8.154845           815.484549
# 2         15        10       5   10.873127          1087.312731
# 3         37        10       5   13.591409          1359.140914
# 4          7        10       5   16.309691          1630.969097
# 5          7        10       5   19.027973          1902.797280
# 6         42        10       5   21.746255          2174.625463
# 7         30        10       5   24.464536          2446.453646
# 8         35        10       5   27.182818          2718.281828
# 9         47        10       5   29.901100          2990.110011

# %%
df['codigo_id']
# Out:
# 0    22
# 1    17
# 2    15
# 3    37
# 4     7
# 5     7
# 6    42
# 7    30
# 8    35
# 9    47
# Name: codigo_id, dtype: int32

# %% [markdown]
# ## <font color=#003d5c>_Modificar una columna_ </font>

# %%
df['indice'] = df['indice'] / 200

df
# Out:
#    codigo_id  años_exp    indice  eficiencia_agregada
# 0         37        10  0.000125           543.656366
# 1         10        10  0.000125           815.484549
# 2         45        10  0.000125          1087.312731
# 3         13        10  0.000125          1359.140914
# 4         15        10  0.000125          1630.969097
# 5         33        10  0.000125          1902.797280
# 6         48        10  0.000125          2174.625463
# 7         34        10  0.000125          2446.453646
# 8         41        10  0.000125          2718.281828
# 9         29        10  0.000125          2990.110011

# %% [markdown]
# ## <font color=#003d5c>_Eliminar una columna o una fila_ </font>

# %%
del df['eficiencia']

df
# Out:
#    codigo_id  años_exp  indice  eficiencia_agregada
# 0         22        10       5           543.656366
# 1         17        10       5           815.484549
# 2         15        10       5          1087.312731
# 3         37        10       5          1359.140914
# 4          7        10       5          1630.969097
# 5          7        10       5          1902.797280
# 6         42        10       5          2174.625463
# 7         30        10       5          2446.453646
# 8         35        10       5          2718.281828
# 9         47        10       5          2990.110011

# %%
c = df.drop([2,3,5], axis=0)
c
# Out:
#    codigo_id  años_exp    indice  eficiencia_agregada
# 0         37        10  0.000125           543.656366
# 1         10        10  0.000125           815.484549
# 4         15        10  0.000125          1630.969097
# 6         48        10  0.000125          2174.625463
# 7         34        10  0.000125          2446.453646
# 8         41        10  0.000125          2718.281828
# 9         29        10  0.000125          2990.110011

# %%
df
# Out:
#    codigo_id  años_exp    indice  eficiencia_agregada
# 0         37        10  0.000125           543.656366
# 1         10        10  0.000125           815.484549
# 2         45        10  0.000125          1087.312731
# 3         13        10  0.000125          1359.140914
# 4         15        10  0.000125          1630.969097
# 5         33        10  0.000125          1902.797280
# 6         48        10  0.000125          2174.625463
# 7         34        10  0.000125          2446.453646
# 8         41        10  0.000125          2718.281828
# 9         29        10  0.000125          2990.110011

# %%
df.drop(['eficiencia_agregada'], axis=1, inplace =  True)

df.head()
# Out:
#    codigo_id  años_exp    indice
# 0         37        10  0.000125
# 1         10        10  0.000125
# 2         45        10  0.000125
# 3         13        10  0.000125
# 4         15        10  0.000125

# %%
df
# Out:
#    codigo_id  años_exp    indice
# 0         37        10  0.000125
# 1         10        10  0.000125
# 2         45        10  0.000125
# 3         13        10  0.000125
# 4         15        10  0.000125
# 5         33        10  0.000125
# 6         48        10  0.000125
# 7         34        10  0.000125
# 8         41        10  0.000125
# 9         29        10  0.000125

# %% [markdown]
# ## <font color=#003d5c>_Modificar el índice_ </font>

# %%
i = ['a','b','c','d','e','f','g','h','i','j']

df.index = i

df
# Out:
#    codigo_id  años_exp    indice
# a         37        10  0.000125
# b         10        10  0.000125
# c         45        10  0.000125
# d         13        10  0.000125
# e         15        10  0.000125
# f         33        10  0.000125
# g         48        10  0.000125
# h         34        10  0.000125
# i         41        10  0.000125
# j         29        10  0.000125

# %%
df["codigo_id"].mean()
# Out:
# 30.5

# %%
df["codigo_id"].sum()
# Out:
# 305

# %%
df["codigo_id"].min()
# Out:
# 10

# %%
df["codigo_id"].max()
# Out:
# 48
