# %% [markdown]
# # EJERCICIOS MINERIA DE DATOS
#
# RONALDO RAFAEL ARIAS PARADA-1151674

# %% [markdown]
# 0. importe pandas

# %%
import pandas as pd

# %% [markdown]
# 1. leer un archivo csv (breast-cancer-wisconsin.data.txt situado en el dataset cancer) en un DataFrame llamado datos. Coloquele los nombres de las columnas como esta especificado en el archivo breast-cancer-wisconsin.names.txt

# %%
datos= pd.read_csv("breast-cancer-wisconsin.data.txt")
datos.columns = ['Sample code number',  'Clump Thickness', 'Uniformity of Cell Size', 'Uniformity of Cell Shape', 
                 'Marginal Adhesion', 'Single Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin', 
                 'Normal Nucleoli', 'Mitoses', 'Class']
datos
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1002945                5                        4
# 1               1015425                3                        1
# 2               1016277                6                        8
# 3               1017023                4                        1
# 4               1017122                8                       10
# ..                  ...              ...                      ...
# 693              776715                3                        1
# 694              841769                2                        1
# 695              888820                5                       10
# 696              897471                4                        8
# 697              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           4                  5                            7
# 1                           1                  1                            2
# 2                           8                  1                            3
# 3                           1                  3                            2
# 4                          10                  8                            7
# ..                        ...                ...                          ...
# 693                         1                  1                            3
# 694                         1                  1                            2
# 695                        10                  3                            7
# 696                         6                  4                            3
# 697                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0            10                3                2        1      2
# 1             2                3                1        1      2
# 2             4                3                7        1      2
# 3             1                3                1        1      2
# 4            10                9                7        1      4
# ..          ...              ...              ...      ...    ...
# 693           2                1                1        1      2
# 694           1                1                1        1      2
# 695           3                8               10        2      4
# 696           4               10                6        1      4
# 697           5               10                4        1      4
#
# [698 rows x 11 columns]

# %% [markdown]
# 2. mostrar las primeras 10 lineas

# %%
datos.head(10)
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1002945                5                        4
# 1             1015425                3                        1
# 2             1016277                6                        8
# 3             1017023                4                        1
# 4             1017122                8                       10
# 5             1018099                1                        1
# 6             1018561                2                        1
# 7             1033078                2                        1
# 8             1033078                4                        2
# 9             1035283                1                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         4                  5                            7
# 1                         1                  1                            2
# 2                         8                  1                            3
# 3                         1                  3                            2
# 4                        10                  8                            7
# 5                         1                  1                            2
# 6                         2                  1                            2
# 7                         1                  1                            2
# 8                         1                  1                            2
# 9                         1                  1                            1
#
#   Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0          10                3                2        1      2
# 1           2                3                1        1      2
# 2           4                3                7        1      2
# 3           1                3                1        1      2
# 4          10                9                7        1      4
# 5          10                3                1        1      2
# 6           1                3                1        1      2
# 7           1                1                1        5      2
# 8           1                2                1        1      2
# 9           1                3                1        1      2

# %% [markdown]
# 3. mostrar las ultimas lineas

# %%
datos.tail(n=5)
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 693              776715                3                        1
# 694              841769                2                        1
# 695              888820                5                       10
# 696              897471                4                        8
# 697              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 693                         1                  1                            3
# 694                         1                  1                            2
# 695                        10                  3                            7
# 696                         6                  4                            3
# 697                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 693           2                1                1        1      2
# 694           1                1                1        1      2
# 695           3                8               10        2      4
# 696           4               10                6        1      4
# 697           5               10                4        1      4

# %% [markdown]
# 4. muestre las dimensiones del DF

# %%
datos.shape
# Out:
# (698, 11)

# %%
print("numero de dimensiones de DataFrame")
datos.ndim
# Out:
# numero de dimensiones de DataFrame
# 2

# %% [markdown]
# 5. muestre las estadísticas del DataFrame

# %%
datos.describe()
# Out:
#        Sample code number  Clump Thickness  Uniformity of Cell Size  \
# count        6.980000e+02       698.000000               698.000000
# mean         1.071807e+06         4.416905                 3.137536
# std          6.175323e+05         2.817673                 3.052575
# min          6.163400e+04         1.000000                 1.000000
# 25%          8.702582e+05         2.000000                 1.000000
# 50%          1.171710e+06         4.000000                 1.000000
# 75%          1.238354e+06         6.000000                 5.000000
# max          1.345435e+07        10.000000                10.000000
#
#        Uniformity of Cell Shape  Marginal Adhesion  \
# count                698.000000         698.000000
# mean                   3.210602           2.809456
# std                    2.972867           2.856606
# min                    1.000000           1.000000
# 25%                    1.000000           1.000000
# 50%                    1.000000           1.000000
# 75%                    5.000000           4.000000
# max                   10.000000          10.000000
#
#        Single Epithelial Cell Size  Bland Chromatin  Normal Nucleoli  \
# count                   698.000000       698.000000       698.000000
# mean                      3.217765         3.438395         2.869628
# std                       2.215408         2.440056         3.055004
# min                       1.000000         1.000000         1.000000
# 25%                       2.000000         2.000000         1.000000
# 50%                       2.000000         3.000000         1.000000
# 75%                       4.000000         5.000000         4.000000
# max                      10.000000        10.000000        10.000000
#
#           Mitoses       Class
# count  698.000000  698.000000
# mean     1.590258    2.690544
# std      1.716162    0.951596
# min      1.000000    2.000000
# 25%      1.000000    2.000000
# 50%      1.000000    2.000000
# 75%      1.000000    4.000000
# max     10.000000    4.000000

# %% [markdown]
# 6. muestre todas las columnas del DF

# %%
print("cantidad de filas y columnas del Dataframe")
print('Columnas : ', len(datos.columns))
print('Filas    : ', len(datos.index))
# Out:
# cantidad de filas y columnas del Dataframe
# Columnas :  11
# Filas    :  698

# %%
datos.columns
# Out:
# Index(['Sample code number', 'Clump Thickness', 'Uniformity of Cell Size',
#        'Uniformity of Cell Shape', 'Marginal Adhesion',
#        'Single Epithelial Cell Size', 'Bare Nuclei', 'Bland Chromatin',
#        'Normal Nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %% [markdown]
# 7. Escribir el DF a un archivo tipo json llamado breast-cancer-wisconsin.data.json

# %%
datos.to_json("breast-cancer-wisconsin.data.json")

print("Leyendo el archivo json escrito")

datos2= pd.read_json("breast-cancer-wisconsin.data.json")
datos2
# Out:
# Leyendo el archivo json escrito
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1002945                5                        4
# 1               1015425                3                        1
# 2               1016277                6                        8
# 3               1017023                4                        1
# 4               1017122                8                       10
# ..                  ...              ...                      ...
# 693              776715                3                        1
# 694              841769                2                        1
# 695              888820                5                       10
# 696              897471                4                        8
# 697              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           4                  5                            7
# 1                           1                  1                            2
# 2                           8                  1                            3
# 3                           1                  3                            2
# 4                          10                  8                            7
# ..                        ...                ...                          ...
# 693                         1                  1                            3
# 694                         1                  1                            2
# 695                        10                  3                            7
# 696                         6                  4                            3
# 697                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0            10                3                2        1      2
# 1             2                3                1        1      2
# 2             4                3                7        1      2
# 3             1                3                1        1      2
# 4            10                9                7        1      4
# ..          ...              ...              ...      ...    ...
# 693           2                1                1        1      2
# 694           1                1                1        1      2
# 695           3                8               10        2      4
# 696           4               10                6        1      4
# 697           5               10                4        1      4
#
# [698 rows x 11 columns]

# %% [markdown]
# 8. -muestre los tipos de datos del DF

# %%
datos.dtypes
# Out:
# Sample code number              int64
# Clump Thickness                 int64
# Uniformity of Cell Size         int64
# Uniformity of Cell Shape        int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Bland Chromatin                 int64
# Normal Nucleoli                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %% [markdown]
# 9. muestre las filas que tienen al menos un Nan y cuentelas

# %%
datos[datos.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Sample code number, Clump Thickness, Uniformity of Cell Size, Uniformity of Cell Shape, Marginal Adhesion, Single Epithelial Cell Size, Bare Nuclei, Bland Chromatin, Normal Nucleoli, Mitoses, Class]
# Index: []

# %%
datos.isnull().sum()
# Out:
# Sample code number             0
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %% [markdown]
# 10. reemplace los valores Nan por la media en las columnas numericas y almacenelo en el dataframe original

# %%
datos.fillna(datos.mean())
# Out:
# C:\Users\RONALD~1\AppData\Local\Temp/ipykernel_7252/2899503409.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   datos.fillna(datos.mean())
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1002945                5                        4
# 1               1015425                3                        1
# 2               1016277                6                        8
# 3               1017023                4                        1
# 4               1017122                8                       10
# ..                  ...              ...                      ...
# 693              776715                3                        1
# 694              841769                2                        1
# 695              888820                5                       10
# 696              897471                4                        8
# 697              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           4                  5                            7
# 1                           1                  1                            2
# 2                           8                  1                            3
# 3                           1                  3                            2
# 4                          10                  8                            7
# ..                        ...                ...                          ...
# 693                         1                  1                            3
# 694                         1                  1                            2
# 695                        10                  3                            7
# 696                         6                  4                            3
# 697                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0            10                3                2        1      2
# 1             2                3                1        1      2
# 2             4                3                7        1      2
# 3             1                3                1        1      2
# 4            10                9                7        1      4
# ..          ...              ...              ...      ...    ...
# 693           2                1                1        1      2
# 694           1                1                1        1      2
# 695           3                8               10        2      4
# 696           4               10                6        1      4
# 697           5               10                4        1      4
#
# [698 rows x 11 columns]

# %% [markdown]
# 11.  Construya una variable dummy para la columna class (2= benigno, 4= maligno) en un Dataframe llamado DF_class

# %%
DF_class = pd.get_dummies(datos['Class'])
DF_class.columns = ['benigno', 'maligno']
DF_class = pd.DataFrame(DF_class)
DF_class
# Out:
#      benigno  maligno
# 0          1        0
# 1          1        0
# 2          1        0
# 3          1        0
# 4          0        1
# ..       ...      ...
# 693        1        0
# 694        1        0
# 695        0        1
# 696        0        1
# 697        0        1
#
# [698 rows x 2 columns]

# %% [markdown]
# 12. una el DF_class como columnas del Df datos

# %%
DF_class = pd.DataFrame(datos)
DF_class = DF_class.drop(['Class'], axis = 1)
DF_new = pd.concat([DF_class, datos], axis = 1)
DF_new
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1002945                5                        4
# 1               1015425                3                        1
# 2               1016277                6                        8
# 3               1017023                4                        1
# 4               1017122                8                       10
# ..                  ...              ...                      ...
# 693              776715                3                        1
# 694              841769                2                        1
# 695              888820                5                       10
# 696              897471                4                        8
# 697              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           4                  5                            7
# 1                           1                  1                            2
# 2                           8                  1                            3
# 3                           1                  3                            2
# 4                          10                  8                            7
# ..                        ...                ...                          ...
# 693                         1                  1                            3
# 694                         1                  1                            2
# 695                        10                  3                            7
# 696                         6                  4                            3
# 697                         8                  5                            4
#
#      Bare Nuclei Bland Chromatin  Normal Nucleoli  Mitoses  ...  \
# 0             10               3                2        1  ...
# 1              2               3                1        1  ...
# 2              4               3                7        1  ...
# 3              1               3                1        1  ...
# 4             10               9                7        1  ...
# ..           ...             ...              ...      ...  ...
# 693            2               1                1        1  ...
# 694            1               1                1        1  ...
# 695            3               8               10        2  ...
# 696            4              10                6        1  ...
# 697            5              10                4        1  ...
#
#      Clump Thickness  Uniformity of Cell Size  Uniformity of Cell Shape  \
# 0                  5                        4                         4
# 1                  3                        1                         1
# 2                  6                        8                         8
# 3                  4                        1                         1
# 4                  8                       10                        10
# ..               ...                      ...                       ...
# 693                3                        1                         1
# 694                2                        1                         1
# 695                5                       10                        10
# 696                4                        8                         6
# 697                4                        8                         8
#
#      Marginal Adhesion  Single Epithelial Cell Size  Bare Nuclei  \
# 0                    5                            7           10
# 1                    1                            2            2
# 2                    1                            3            4
# 3                    3                            2            1
# 4                    8                            7           10
# ..                 ...                          ...          ...
# 693                  1                            3            2
# 694                  1                            2            1
# 695                  3                            7            3
# 696                  4                            3            4
# 697                  5                            4            5
#
#     Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0                 3                2        1      2
# 1                 3                1        1      2
# 2                 3                7        1      2
# 3                 3                1        1      2
# 4                 9                7        1      4
# ..              ...              ...      ...    ...
# 693               1                1        1      2
# 694               1                1        1      2
# 695               8               10        2      4
# 696              10                6        1      4
# 697              10                4        1      4
#
# [698 rows x 21 columns]

# %% [markdown]
# 13. Muestre el histograma de cada columna

# %%
datos.plot(kind = 'hist')
print("DataFrame datos")
# Out:
# DataFrame datos

# %%
DF_new.plot(kind = 'hist')
print("DataFrame datos unido con el DataFrame Class")
# Out:
# DataFrame datos unido con el DataFrame Class

# %% [markdown]
# 14. Realice el diagrama de caja y bigotes de todas las columnas

# %%
datos[["Sample code number","Clump Thickness","Uniformity of Cell Size","Uniformity of Cell Shape","Marginal Adhesion","Single Epithelial Cell Size","Bare Nuclei","Bland Chromatin","Normal Nucleoli","Mitoses","Class"]].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 15. Cree un nuevo DF sin la columna class llamado datos_sin_class

# %%
datos = pd.DataFrame(datos)
datos_sin_class = datos.drop(['Class'],axis=1)
datos_sin_class
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1002945                5                        4
# 1               1015425                3                        1
# 2               1016277                6                        8
# 3               1017023                4                        1
# 4               1017122                8                       10
# ..                  ...              ...                      ...
# 693              776715                3                        1
# 694              841769                2                        1
# 695              888820                5                       10
# 696              897471                4                        8
# 697              897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           4                  5                            7
# 1                           1                  1                            2
# 2                           8                  1                            3
# 3                           1                  3                            2
# 4                          10                  8                            7
# ..                        ...                ...                          ...
# 693                         1                  1                            3
# 694                         1                  1                            2
# 695                        10                  3                            7
# 696                         6                  4                            3
# 697                         8                  5                            4
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses
# 0            10                3                2        1
# 1             2                3                1        1
# 2             4                3                7        1
# 3             1                3                1        1
# 4            10                9                7        1
# ..          ...              ...              ...      ...
# 693           2                1                1        1
# 694           1                1                1        1
# 695           3                8               10        2
# 696           4               10                6        1
# 697           5               10                4        1
#
# [698 rows x 10 columns]

# %% [markdown]
# 16. Muestre la fila 4 y 15 de datos

# %%
datos.iloc[[4,15]]
# Out:
#     Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 4              1017122                8                       10
# 15             1048672                4                        1
#
#     Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 4                         10                  8                            7
# 15                         1                  1                            2
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 4           10                9                7        1      4
# 15           1                2                1        1      2

# %% [markdown]
# 17. muestre la fila 8 y 10 con solo las columnas 1, 3, 6 de datos

# %%
condicion = datos.loc[:,['Sample code number', 'Uniformity of Cell Size', 'Single Epithelial Cell Size']] 
condicion.iloc[[8,10]]
# Out:
#     Sample code number  Uniformity of Cell Size  Single Epithelial Cell Size
# 8              1033078                        2                            2
# 10             1036172                        1                            2

# %% [markdown]
# 18. muestre las filas 11, 15, 18 con las columnas de datos Sample code number y Clump Thickness

# %%
condicion = datos.loc[:,['Sample code number', 'Clump Thickness']] 
condicion.iloc[[11,15,18]]
# Out:
#     Sample code number  Clump Thickness
# 11             1041801                5
# 15             1048672                4
# 18             1050718                6

# %% [markdown]
# 19. Realice una grafica tipo scatter que muestre la relacion entre "class" y "Single Epithelial Cell Size"

# %%
datos.plot(kind="scatter", x="Class", y="Single Epithelial Cell Size")
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Single Epithelial Cell Size'>

# %% [markdown]
# 20. muestre las filas cuya "Single Epithelial Cell Size" sea mayor a 5

# %%
condicion = datos[datos['Single Epithelial Cell Size']>5]
condicion
# Out:
#      Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0               1002945                5                        4
# 4               1017122                8                       10
# 13              1044572                8                        7
# 14              1047630                7                        4
# 20              1054593               10                        5
# ..                  ...              ...                      ...
# 635             1268952               10                       10
# 647             1315807                5                       10
# 656             1333877                5                        4
# 667             1350319                5                        7
# 695              888820                5                       10
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           4                  5                            7
# 4                          10                  8                            7
# 13                          5                 10                            7
# 14                          6                  4                            6
# 20                          5                  3                            6
# ..                        ...                ...                          ...
# 635                         7                  8                            7
# 647                        10                 10                           10
# 656                         5                  1                            8
# 667                         4                  1                            6
# 695                        10                  3                            7
#
#     Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0            10                3                2        1      2
# 4            10                9                7        1      4
# 13            9                5                5        4      4
# 14            1                4                3        1      4
# 20            7                7               10        1      4
# ..          ...              ...              ...      ...    ...
# 635           1               10               10        3      4
# 647           2               10               10       10      4
# 656           1                3                6        1      2
# 667           1                7               10        3      4
# 695           3                8               10        2      4
#
# [107 rows x 11 columns]
